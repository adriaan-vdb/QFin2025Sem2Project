# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import statsmodels.formula.api as smf
#
# File /opt/miniconda3/envs/qfin_env/lib/python3.12/site-packages/statsmodels/__init__.py:1
# ----> 1 from statsmodels.compat.patsy import monkey_patch_cat_dtype
#       3 from statsmodels._version import __version__, __version_tuple__
#       5 __version_info__ = __version_tuple__
#
# File /opt/miniconda3/envs/qfin_env/lib/python3.12/site-packages/statsmodels/compat/__init__.py:1
# ----> 1 from statsmodels.tools._test_runner import PytestTester
#       3 from .python import (
#       4     asunicode,
#       5     asbytes,
#    (...)     10     lfilter,
#      11 )
#      13 __all__ = [
#      14     "asunicode",
#      15     "asbytes",
#    (...)     21     "test",
#      22 ]
#
# ...

# %%
df = pd.read_csv("prices.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Bids    Asks
# 0           0    NaN     NaN
# 1           1  998.0  1002.0
# 2           2  997.5  1001.5
# 3           3  996.5  1001.5
# 4           4  996.0  1000.0

# %%
df['Mids'] = (df["Bids"] + df["Asks"])/2

# %%
plt.plot(df['Mids'])

# %%
a = np.exp(np.random.normal(0, .001, 1000))
plt.plot(a)
plt.show()

# %%
## Calculating returns
ticker = 400
df["Trailing_Returns_5"] = (df["Mids"] - df ["Mids"].shift(ticker)) / df ["Mids"].shift(ticker)

df["Forward_Returns_5"] = (df["Mids"].shift(-ticker) - df["Mids"]) / df["Mids"]

# %%
# Remove NaN values for plotting
df_clean = df.dropna()

plt.plot(df_clean["Trailing_Returns_5"], df_clean["Forward_Returns_5"], "o", alpha=0.6)
plt.xlabel("Trailing Returns (5-period)")
plt.ylabel("Forward Returns (5-period)")
plt.title("Trailing vs Forward Returns")
plt.grid(True, alpha=0.3, linestyle='--')
plt.show()

# %%
smf.ols["Forwards_Returns_5s - Trailing_returns_5s"], data=df.fit().summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/kc/xfz7r5k92kj432bvhtjm8hrr0000gn/T/ipykernel_509/2568898115.py in ?()
# ----> 1 smf.ols["Forwards_Returns_5s - Trailing_returns_5s"], data=df.fit().summary()
#
# /opt/miniconda3/envs/qfin_env/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'fit'
