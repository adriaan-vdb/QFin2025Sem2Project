# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# df.head()
# Out:
#    Unnamed: 0   Bids    Asks
# 0           0    NaN     NaN
# 1           1  998.0  1002.0
# 2           2  996.4  1001.4
# 3           3  995.4  1000.4
# 4           4  994.6  1000.6

# %%
df = pd.read_csv("prices.csv")

plt.plot(df["Bids"], label="Bids")
plt.plot(df["Asks"], label="Asks")
plt.legend()
plt.savefig("prices_plot_1.svg", format='svg')  # Save as a vector image
plt.show()
